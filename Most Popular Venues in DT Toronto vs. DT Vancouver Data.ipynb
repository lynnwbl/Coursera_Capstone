# %% [markdown]
# # Most Popular Venues in Downtown Toronto VS. Downtown Vancouver

# %% [markdown]
# ## Introduction

# %% [markdown]
# ###  Vancouver is the largest city in western Canada. As the most populous city in the British Columbia, there are many similarities between Vancouver and Toronto, the most populous city in Ontario.
# ### This project aims to explore the similarities and dissimilarities between Downtown Toronto and Downtown Vancouver by analyzing the most popular venues in the neighbourhoods.

# %% [markdown]
# ## Data

# %% [markdown]
# The data that will be used in this analysis are Foursquare location data. Segmentation and clustering with k-means will be implemented. Visualization will be
